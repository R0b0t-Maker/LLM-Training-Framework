# %% [markdown]
# <a href="https://colab.research.google.com/github/R0b0t-Maker/LLM-T/blob/main/LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from transformers import pipeline, set_seed

# def get_model_response(model_name, prompt):
#     generator = pipeline('text-generation', model=model_name)
#     set_seed(42)  # Setting a seed for reproducibility
#     response = generator(prompt, max_length=50, num_return_sequences=1)
#     return response[0]['generated_text']

# # Define a prompt to use for comparison
# prompt = "The future of AI in society is"

# # List of model names available on Hugging Face
# models = [
#     "gpt2",        # GPT-2 model
#     "distilbert-base-uncased",  # DistilBERT model
#     # Add other models here
# ]

# # Getting and printing responses from each model
# for model in models:
#     try:
#         response = get_model_response(model, prompt)
#         print(f"Response from {model}:\n{response}\n")
#     except Exception as e:
#         print(f"Error with model {model}: {e}")


from transformers import pipeline, set_seed

def get_model_response(model_name, prompt):
    generator = pipeline('text-generation', model=model_name)
    set_seed(42)  # Setting a seed for reproducibility
    response = generator(prompt, max_length=50, num_return_sequences=1)
    return response[0]['generated_text']

# Define a prompt to use for comparison
prompt = "The future of AI in society is"

# Updated list of model names for text generation
models = [
    "gpt2",             # GPT-2 model
    "EleutherAI/gpt-neo-1.3B",  # GPT-Neo model
    "EleutherAI/gpt-j-6B",      # GPT-J model
    # Add other models here
]

# Getting and printing responses from each model
for model in models:
    try:
        response = get_model_response(model, prompt)
        print(f"Response from {model}:\n{response}\n")
    except Exception as e:
        print(f"Error with model {model}: {e}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Response from gpt2:
# The future of AI in society is unknown. But some people believe that the idea is not true, and that this system will, under those conditions, eventually become the computer: so-called AI will be able to understand and help people, by communicating
# config.json:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/5.31G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d20f5c75840a> in <cell line: 48>()
#      48 for model in models:
#      49     try:
# ---> 50         response = get_model_response(model, prompt)
#      51         print(f"Response from {model}:\n{response}\n")
#      52     except Exception as e:
#
# <ipython-input-4-d20f5c75840a> in get_model_response(model_name, prompt)
#      29
# ...
